# %%
# !git clone https://github.com/youcan0827/todo-app.git
# %cd todo-app
# Out:
# Cloning into 'todo-app'...
# remote: Enumerating objects: 83, done.
# remote: Counting objects: 100% (83/83), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 83 (delta 44), reused 61 (delta 23), pack-reused 0 (from 0)
# Receiving objects: 100% (83/83), 1.40 MiB | 21.44 MiB/s, done.
# Resolving deltas: 100% (44/44), done.
# /content/todo-app

# %%
# !pip install -q langchain langchain-openai python-dotenv torch diffusers
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.3/475.3 kB 17.7 MB/s eta 0:00:00

# %%
# !pip install -U git+https://github.com/huggingface/diffusers git+https://github.com/Disty0/sdnq
# Out:
# Collecting git+https://github.com/huggingface/diffusers
#   Cloning https://github.com/huggingface/diffusers to /tmp/pip-req-build-_seip5g0
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/diffusers /tmp/pip-req-build-_seip5g0
#   Resolved https://github.com/huggingface/diffusers to commit 17c0e79dbdf53fb6705e9c09cc1a854b84c39249
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting git+https://github.com/Disty0/sdnq
#   Cloning https://github.com/Disty0/sdnq to /tmp/pip-req-build-t4dau3e9
#   Running command git clone --filter=blob:none --quiet https://github.com/Disty0/sdnq /tmp/pip-req-build-t4dau3e9
#   Resolved https://github.com/Disty0/sdnq to commit 5517e63041961758991ebc1dcfe8f28af7381cc9
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.12/dist-packages (from diffusers==0.36.0.dev0) (8.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from diffusers==0.36.0.dev0) (3.20.0)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from diffusers==0.36.0.dev0) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from diffusers==0.36.0.dev0) (0.36.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from diffusers==0.36.0.dev0) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from diffusers==0.36.0.dev0) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from diffusers==0.36.0.dev0) (2.32.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from diffusers==0.36.0.dev0) (0.7.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from diffusers==0.36.0.dev0) (11.3.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from sdnq==0.1.3) (2.9.0+cu126)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from sdnq==0.1.3) (4.57.3)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (from sdnq==0.1.3) (1.12.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers==0.36.0.dev0) (4.12.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers==0.36.0.dev0) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers==0.36.0.dev0) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers==0.36.0.dev0) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->diffusers==0.36.0.dev0) (0.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers==0.36.0.dev0) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers==0.36.0.dev0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers==0.36.0.dev0) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers==0.36.0.dev0) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers==0.36.0.dev0) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers==0.36.0.dev0) (1.2.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate->sdnq==0.1.3) (5.9.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->sdnq==0.1.3) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->sdnq==0.1.3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->sdnq==0.1.3) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->sdnq==0.1.3) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->sdnq==0.1.3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->sdnq==0.1.3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->sdnq==0.1.3) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->sdnq==0.1.3) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->sdnq==0.1.3) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->sdnq==0.1.3) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->sdnq==0.1.3) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->sdnq==0.1.3) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->sdnq==0.1.3) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->sdnq==0.1.3) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->sdnq==0.1.3) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->sdnq==0.1.3) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->sdnq==0.1.3) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->sdnq==0.1.3) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->sdnq==0.1.3) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->sdnq==0.1.3) (3.5.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata->diffusers==0.36.0.dev0) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers==0.36.0.dev0) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers==0.36.0.dev0) (2.5.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->sdnq==0.1.3) (0.22.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->sdnq==0.1.3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->sdnq==0.1.3) (3.0.3)
# Building wheels for collected packages: diffusers, sdnq
#   Building wheel for diffusers (pyproject.toml) ... done
#   Created wheel for diffusers: filename=diffusers-0.36.0.dev0-py3-none-any.whl size=4634817 sha256=dcb3488fec3ad147363ea0c55407cd7fa0175756b4f6da45df82d4aa0e479942
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6qkywnka/wheels/90/d4/44/a58bc00fb405fefb633b0d9d2307f6e3aec6cc1775d82555d3
#   Building wheel for sdnq (pyproject.toml) ... done
#   Created wheel for sdnq: filename=sdnq-0.1.3-py3-none-any.whl size=89500 sha256=e04c9d62103a38eaf82e46ffc733b2dfb04136558910e91e33ea73cb0bc25c65
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6qkywnka/wheels/73/03/e1/20cc6f9344abc9d279eb79cb5c0e17155f8b229c425d4ffc90
# Successfully built diffusers sdnq
# Installing collected packages: diffusers, sdnq
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.36.0
#     Uninstalling diffusers-0.36.0:
#       Successfully uninstalled diffusers-0.36.0
# Successfully installed diffusers-0.36.0.dev0 sdnq-0.1.3

# %%
# !python main.py
# Out:
# CLI TODO管理アプリへようこそ！
#
# ========================================
#          CLI TODO管理アプリ
# ========================================
# 1. タスク追加
# 2. タスク確認
# 3. タスク完了
# 4. 自然言語モード
# 5. 終了
# ========================================
# 選択してください (1-5): 3
#
# === タスク完了 ===
# 未完了のタスク:
# [No.1] 支払い (期限: 2025-08-22)
# [No.2] 朝から仕事 (期限: 2023-10-06)
# [No.3] バスケ (期限: 2025-2-10)
# [No.4] サッカー (期限: 2025-09-12)
# [No.5] 吉野くんとMTGする (期限: 2022-01-10)
#
# 完了するタスクの番号を入力してください: 3
# タスク「バスケ」を完了しました。
#
# おめでとうございます！タスクを完了しました。
# 今の気分を教えてください（例: 嬉しい、達成感、リラックスなど）: ほっとする
# 画像生成モデルを読み込んでいます...
# ほっとする
# 2025-12-12 08:37:30.160407: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765528650.180077    1153 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765528650.185928    1153 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765528650.200917    1153 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765528650.200941    1153 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765528650.200945    1153 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765528650.200948    1153 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-12 08:37:30.205402: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# model_index.json: 100% 457/457 [00:00<00:00, 2.96MB/s]
# Fetching 12 files:   0% 0/12 [00:00<?, ?it/s]
# merges.txt: 0.00B [00:00, ?B/s]
#
# vocab.json: 0.00B [00:00, ?B/s]
#
#
# scheduler_config.json: 100% 487/487 [00:00<00:00, 3.72MB/s]
# merges.txt: 1.67MB [00:00, 29.3MB/s]
# vocab.json: 2.78MB [00:00, 60.2MB/s]
#
# config.json: 1.33kB [00:00, 9.89MB/s]
#
# config.json: 100% 920/920 [00:00<00:00, 10.0MB/s]
#
# tokenizer_config.json: 9.73kB [00:00, 39.9MB/s]
#
# text_encoder/model.safetensors:   0% 0.00/2.84G [00:00<?, ?B/s]
#
# tokenizer/tokenizer.json:   0% 0.00/11.4M [00:00<?, ?B/s]
#
#
# config.json: 2.68kB [00:00, 15.4MB/s]
#
#
#
# transformer/diffusion_pytorch_model.safe(…):   0% 0.00/3.48G [00:00<?, ?B/s]
#
#
#
# vae/diffusion_pytorch_model.safetensors:   0% 0.00/168M [00:00<?, ?B/s]
#
# tokenizer/tokenizer.json: 100% 11.4M/11.4M [00:00<00:00, 20.9MB/s]
#
#
#
#
# vae/diffusion_pytorch_model.safetensors:  40% 67.1M/168M [00:00<00:01, 83.8MB/s]
# text_encoder/model.safetensors:   0% 393k/2.84G [00:01<3:18:13, 239kB/s]
#
#
#
# vae/diffusion_pytorch_model.safetensors: 100% 168M/168M [00:05<00:00, 28.7MB/s]
#
# text_encoder/model.safetensors:   1% 38.0M/2.84G [00:08<10:20, 4.52MB/s]
# text_encoder/model.safetensors:   6% 172M/2.84G [00:09<01:46, 25.1MB/s]
# text_encoder/model.safetensors:  11% 306M/2.84G [00:09<00:49, 51.2MB/s]
# text_encoder/model.safetensors:  14% 403M/2.84G [00:10<00:37, 65.6MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):   2% 67.0M/3.48G [00:10<09:09, 6.21MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):   3% 103M/3.48G [00:11<05:24, 10.4MB/s]
# text_encoder/model.safetensors:  19% 527M/2.84G [00:11<00:28, 82.0MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):   8% 277M/3.48G [00:11<01:21, 39.3MB/s]
# text_encoder/model.safetensors:  20% 568M/2.84G [00:11<00:26, 86.8MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  10% 344M/3.48G [00:11<01:00, 52.0MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  12% 411M/3.48G [00:14<01:15, 40.9MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  16% 545M/3.48G [00:14<00:42, 69.2MB/s]
# text_encoder/model.safetensors:  23% 644M/2.84G [00:14<00:45, 48.3MB/s]
# text_encoder/model.safetensors:  25% 711M/2.84G [00:15<00:35, 60.8MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  17% 582M/3.48G [00:15<00:45, 63.6MB/s]
# text_encoder/model.safetensors:  30% 845M/2.84G [00:16<00:23, 84.7MB/s]
# text_encoder/model.safetensors:  32% 912M/2.84G [00:16<00:22, 86.5MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  19% 665M/3.48G [00:17<00:47, 58.8MB/s]
# Fetching 12 files:  17% 2/12 [00:17<00:00, 12.50it/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  22% 753M/3.48G [00:17<00:36, 74.9MB/s]
# text_encoder/model.safetensors:  37% 1.05G/2.84G [00:17<00:17, 99.9MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  24% 820M/3.48G [00:22<01:17, 34.4MB/s]
# text_encoder/model.safetensors:  40% 1.13G/2.84G [00:22<00:43, 39.5MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  27% 954M/3.48G [00:22<00:45, 55.3MB/s]
# text_encoder/model.safetensors:  42% 1.20G/2.84G [00:23<00:34, 47.0MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  30% 1.04G/3.48G [00:23<00:37, 65.9MB/s]
# text_encoder/model.safetensors:  45% 1.26G/2.84G [00:23<00:26, 58.9MB/s]
# text_encoder/model.safetensors:  47% 1.33G/2.84G [00:23<00:19, 78.8MB/s]
# text_encoder/model.safetensors:  49% 1.40G/2.84G [00:24<00:14, 98.4MB/s]
# text_encoder/model.safetensors:  52% 1.47G/2.84G [00:24<00:11, 120MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  31% 1.07G/3.48G [00:26<00:57, 41.7MB/s]
# text_encoder/model.safetensors:  54% 1.53G/2.84G [00:26<00:19, 66.1MB/s]
# text_encoder/model.safetensors:  59% 1.67G/2.84G [00:26<00:11, 105MB/s]
# text_encoder/model.safetensors:  61% 1.73G/2.84G [00:27<00:08, 130MB/s]
# text_encoder/model.safetensors:  63% 1.80G/2.84G [00:27<00:06, 154MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  33% 1.14G/3.48G [00:27<00:53, 43.9MB/s]
# text_encoder/model.safetensors:  66% 1.87G/2.84G [00:27<00:06, 149MB/s]
# text_encoder/model.safetensors:  69% 1.96G/2.84G [00:28<00:05, 172MB/s]
# text_encoder/model.safetensors:  71% 2.02G/2.84G [00:28<00:04, 187MB/s]
# text_encoder/model.safetensors:  74% 2.09G/2.84G [00:28<00:04, 186MB/s]
# text_encoder/model.safetensors:  76% 2.16G/2.84G [00:29<00:03, 210MB/s]
# text_encoder/model.safetensors:  78% 2.22G/2.84G [00:29<00:03, 163MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  35% 1.21G/3.48G [00:30<01:00, 37.4MB/s]
# text_encoder/model.safetensors:  81% 2.29G/2.84G [00:30<00:04, 123MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  37% 1.28G/3.48G [00:31<00:56, 38.9MB/s]
# text_encoder/model.safetensors:  82% 2.34G/2.84G [00:32<00:06, 74.8MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  39% 1.34G/3.48G [00:32<00:43, 49.1MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  40% 1.41G/3.48G [00:32<00:32, 63.9MB/s]
# text_encoder/model.safetensors:  85% 2.41G/2.84G [00:32<00:05, 73.0MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  42% 1.48G/3.48G [00:33<00:27, 74.3MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  44% 1.54G/3.48G [00:33<00:21, 92.2MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  45% 1.57G/3.48G [00:33<00:19, 98.0MB/s]
# text_encoder/model.safetensors:  87% 2.48G/2.84G [00:33<00:05, 71.6MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  47% 1.64G/3.48G [00:34<00:20, 90.0MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  49% 1.71G/3.48G [00:34<00:15, 112MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  51% 1.78G/3.48G [00:34<00:11, 146MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  53% 1.84G/3.48G [00:35<00:10, 150MB/s]
# text_encoder/model.safetensors:  93% 2.64G/2.84G [00:35<00:02, 87.6MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  54% 1.88G/3.48G [00:35<00:10, 147MB/s]
# text_encoder/model.safetensors:  95% 2.71G/2.84G [00:36<00:01, 91.7MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  56% 1.94G/3.48G [00:36<00:11, 134MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  58% 2.01G/3.48G [00:36<00:09, 163MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  60% 2.08G/3.48G [00:36<00:07, 188MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  62% 2.14G/3.48G [00:36<00:06, 195MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  63% 2.21G/3.48G [00:37<00:05, 213MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  65% 2.28G/3.48G [00:37<00:05, 235MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  67% 2.34G/3.48G [00:37<00:04, 264MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  69% 2.41G/3.48G [00:38<00:05, 197MB/s]
# text_encoder/model.safetensors:  98% 2.77G/2.84G [00:38<00:01, 61.5MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  71% 2.48G/3.48G [00:38<00:05, 186MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  73% 2.55G/3.48G [00:40<00:12, 72.3MB/s]
# text_encoder/model.safetensors: 100% 2.84G/2.84G [00:40<00:00, 69.4MB/s]
# Fetching 12 files:  33% 4/12 [00:41<01:37, 12.13s/it]
#
#
# transformer/diffusion_pytorch_model.safe(…):  75% 2.61G/3.48G [00:40<00:09, 96.0MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  77% 2.68G/3.48G [00:41<00:06, 129MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  79% 2.75G/3.48G [00:41<00:04, 161MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  81% 2.81G/3.48G [00:41<00:03, 198MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  83% 2.88G/3.48G [00:41<00:02, 213MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  85% 2.95G/3.48G [00:41<00:02, 225MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  87% 3.02G/3.48G [00:42<00:02, 229MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  88% 3.08G/3.48G [00:42<00:01, 232MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  90% 3.15G/3.48G [00:42<00:01, 244MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  92% 3.22G/3.48G [00:43<00:01, 213MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  94% 3.28G/3.48G [00:43<00:01, 143MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  96% 3.35G/3.48G [00:44<00:00, 159MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…):  98% 3.42G/3.48G [00:44<00:00, 203MB/s]
#
#
# transformer/diffusion_pytorch_model.safe(…): 100% 3.48G/3.48G [00:44<00:00, 78.0MB/s]
# Fetching 12 files: 100% 12/12 [00:45<00:00,  3.76s/it]
# Loading pipeline components...:  60% 3/5 [00:11<00:07,  3.75s/it]`torch_dtype` is deprecated! Use `dtype` instead!
# Loading pipeline components...: 100% 5/5 [00:25<00:00,  5.03s/it]
# モデルの読み込みが完了しました。
# 🎨 画像を生成しています...
# /usr/local/lib/python3.12/dist-packages/torch/backends/cuda/__init__.py:131: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   return torch._C._get_cublas_allow_tf32()
# W1212 08:38:50.327000 1153 torch/_inductor/utils.py:1558] [2/0] Not enough SMs to use max_autotune_gemm mode
# 100% 9/9 [01:04<00:00,  7.15s/it]
# 🎉 タスク完了！画像を保存しました。
# 🌐 環境: Colab
# 📂 保存場所: /content/todo-app/generated_images/celebration_ほっとする_20251212_084010.png
# 📁 Colabファイルブラウザで確認できます
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024 at 0x7B0EC27B2F90>
#
# ========================================
#          CLI TODO管理アプリ
# ========================================
# 1. タスク追加
# 2. タスク確認
# 3. タスク完了
# 4. 自然言語モード
# 5. 終了
# ========================================
# 選択してください (1-5): エラー: 1-5の数字を入力してください。
#
# ========================================
#          CLI TODO管理アプリ
# ========================================
# 1. タスク追加
# 2. タスク確認
# 3. タスク完了
# 4. 自然言語モード
# 5. 終了
# ========================================
# 選択してください (1-5): ^C
